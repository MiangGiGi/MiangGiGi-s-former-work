# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('null','null','null','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 


# # 以下定义各种SQL操作
# def QuerySeller():
#     sql_query="select * from 卖家"    #查看交易详情
#     cursor.execute(sql_query)   #执行某一SQL操作
#     res=cursor.fetchall()   #操作结果付给res
#     for record in res:      #record是res中的每个元组
#         for col in range(len(record)):
#             showtxt=str(record[col])
#             print (showtxt,end=" ")
#         print()        #输出每个分量
        
# def QueryBuyer():
#     sql_query="select * from 买家"    #查看交易详情
#     cursor.execute(sql_query)   #执行某一SQL操作
#     res=cursor.fetchall()   #操作结果付给res
#     for record in res:      #record是res中的每个元组
#         for col in range(len(record)):
#             showtxt=str(record[col])
#             print (showtxt,end=" ")
#         print()        #输出每个分量
        
# def QueryGoods():
#     sql_query="select * from 出售的商品"    #查看交易详情
#     cursor.execute(sql_query)   #执行某一SQL操作
#     res=cursor.fetchall()   #操作结果付给res
#     for record in res:      #record是res中的每个元组
#         for col in range(len(record)):
#             showtxt=str(record[col])
#             print (showtxt,end=" ")
#         print()        #输出每个分量
        
# def QueryTrade():
#     sql_query="select * from 交易详情"    #查看交易详情
#     cursor.execute(sql_query)   #执行某一SQL操作
#     res=cursor.fetchall()   #操作结果付给res
#     for record in res:      #record是res中的每个元组
#         for col in range(len(record)):
#             showtxt=str(record[col])
#             print (showtxt,end=" ")
#         print()        #输出每个分量
        

          

        
def InsertSeller(name):
    sql_insert="insert into 卖家 values('%s')"%(name)
    cursor.execute(sql_insert)   #执行某一SQL操作
    conn.commit()

def qs(event):
    l1["text"]=""
    sql_query="select * from 卖家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量
        
    
def qb(event):
    l1["text"]=""
    sql_query="select * from 买家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量
        
def qt(event):
    l1["text"]=""
    sql_query="select * from 交易详情"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量
        
def qg(event):
    l1["text"]=""
    sql_query="select * from 出售的商品"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量
        

# 创建GUI
win=Tk()
f1=Frame(win)
f1.pack()
butt_qs=Button(f1,text="查询卖家")
butt_qs.pack(side='bottom')
butt_qb=Button(f1,text="查询买家")
butt_qb.pack(side='bottom')
butt_qg=Button(f1,text="查询商品")
butt_qg.pack(side='bottom')
butt_qt=Button(f1,text="查询交易")
butt_qt.pack(side='bottom')
l1=Label(f1)
l1.pack()

butt_qs.bind('<1>',qs)
butt_qb.bind('<1>',qb)
butt_qt.bind('<1>',qt)
butt_qg.bind('<1>',qg)
win.mainloop()

# QuerySeller()
# name='王大锤手机店'
# InsertSeller(name)
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 分割线--------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 输入卖家

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def InsertSeller():
    name='v'
    sql_insert="insert into 卖家 values('%s')"%(expression.get())
    cursor.execute(sql_insert)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    
def qs():
    l1["text"]=""
    sql_query="select * from 卖家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量
# butt_qs1=Button(f1,text="查询卖家信息",command=qs)
# butt_qs1.pack(side='bottom')
    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()
f1.pack()
entry.pack()
expression=StringVar()
entry["textvariable"]=expression
empty=StringVar()
empty.set('Done')

butt_qs=Button(f1,text="输入卖家信息",command=InsertSeller)
butt_qs.pack(side='bottom')
butt_qs1=Button(f1,text="查询卖家信息",command=qs)
butt_qs1.pack(side='bottom')


l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "src\\pymssql\\_pymssql.pyx", line 459, in pymssql._pymssql.Cursor.execute
#   File "src\\pymssql\\_mssql.pyx", line 1113, in pymssql._mssql.MSSQLConnection.execute_query
#   File "src\\pymssql\\_mssql.pyx", line 1144, in pymssql._mssql.MSSQLConnection.execute_query
#   File "src\\pymssql\\_mssql.pyx", line 1277, in pymssql._mssql.MSSQLConnection.format_and_run_query
#   File "src\\pymssql\\_mssql.pyx", line 1815, in pymssql._mssql.check_cancel_and_raise
#   File "src\\pymssql\\_mssql.pyx", line 1861, in pymssql._mssql.raise_MSSQLDatabaseException
# pymssql._mssql.MSSQLDatabaseException: (2627, b"Violation of PRIMARY KEY constraint 'PK_\xe5\x8d\x96\xe5\xae\xb6_1'. Cannot insert duplicate key in object 'dbo.\xe5\x8d\x96\xe5\xae\xb6'. The duplicate key value is (jjj).DB-Lib error message 20018, severity 14:\nGeneral SQL Server error: Check messages from the SQL Server\n")
#
# ...

# %% [markdown]
# # 输入买家

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def InsertBuyer():
    sql_insert="insert into 买家 values('%s')"%(expression.get())
    cursor.execute(sql_insert)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    
def qb():
    l1["text"]=""
    sql_query="select * from 买家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量
# butt_qs=Button(f1,text="查询买家信息",command=qb)
# butt_qs.pack(side='bottom')


# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()

f1.pack()
entry.pack()

expression=StringVar()
entry["textvariable"]=expression

empty=StringVar()
empty.set('Done')


butt_qs=Button(f1,text="输入买家信息",command=InsertBuyer)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询买家信息",command=qb)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 输入商品

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def InsertBuyer():
    sql_insert="insert into 出售的商品 values('%s','%s','%s',%s)"%(expression.get(),expression1.get(),expression2.get(),expression3.get())
    cursor.execute(sql_insert)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    entry1["textvariable"]=empty
    entry2["textvariable"]=empty
    entry3["textvariable"]=empty
    
    
def qg():
    l1["text"]=""
    sql_query="select * from 出售的商品"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量
# butt_qs=Button(f1,text="查询商品信息",command=qg)
# butt_qs.pack(side='bottom')

        

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1,textvariable=e)

entry1=Entry(f1)
entry2=Entry(f1)
entry3=Entry(f1)
entry.focus()

f1.pack()
entry.pack()
entry1.pack()
entry2.pack()
entry3.pack()

expression=StringVar()
expression1=StringVar()
expression2=StringVar()
expression3=StringVar()
entry["textvariable"]=expression
entry1["textvariable"]=expression1
entry2["textvariable"]=expression2
entry3["textvariable"]=expression3

empty=StringVar()
empty.set('Done')


butt_qs=Button(f1,text="输入商品信息",command=InsertBuyer)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询商品信息",command=qg)
butt_qs.pack(side='bottom')


l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 输入交易详情

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def InsertBuyer():
    sql_insert="insert into 交易详情 values('%s','%s','%s','%s','%s')"%(expression.get(),expression1.get(),expression3.get(),expression4.get(),expression5.get())
    cursor.execute(sql_insert)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    entry1["textvariable"]=empty
#     entry2["textvariable"]=empty
    entry3["textvariable"]=empty
    entry4["textvariable"]=empty
    entry5["textvariable"]=empty
#     entry6["textvariable"]=empty
    
def qt():
    l1["text"]=""
    sql_query="select * from 交易详情"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量
# butt_qs=Button(f1,text="查询交易信息",command=qt)
# butt_qs.pack(side='bottom')
        

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry1=Entry(f1)
# entry2=Entry(f1)
entry3=Entry(f1)
entry4=Entry(f1)
entry5=Entry(f1)
# entry6=Entry(f1)


entry.focus()

f1.pack()
entry.pack()
entry1.pack()
# entry2.pack()
entry3.pack()
entry4.pack()
entry5.pack()
# entry6.pack()

expression=StringVar()
expression1=StringVar()
# expression2=StringVar()
expression3=StringVar()
expression4=StringVar()
expression5=StringVar()
# expression6=StringVar()
entry["textvariable"]=expression
entry1["textvariable"]=expression1
# entry2["textvariable"]=expression2
entry3["textvariable"]=expression3
entry4["textvariable"]=expression4
entry5["textvariable"]=expression5
# entry6["textvariable"]=expression6

empty=StringVar()
empty.set('Done')


butt_qs=Button(f1,text="输入交易信息",command=InsertBuyer)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询交易信息",command=qt)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # —————————————————————————————————————————————————————————————————————分割线——————————————————————————————————————————————————————————————————————————————

# %% [markdown]
# # 删除卖家

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def DeleteSeller():
    sql_delete="Delete  From  卖家   Where  卖家名称 ='%s'"%(expression.get())
    cursor.execute(sql_delete)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    
    
def qs():
    l1["text"]=""
    sql_query="select * from 卖家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量

    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()
f1.pack()
entry.pack()
expression=StringVar()
empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression

butt_qs=Button(f1,text="删除卖家信息",command=DeleteSeller)
butt_qs.pack(side='bottom')
butt_qs1=Button(f1,text="查询卖家信息",command=qs)
butt_qs1.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 删除买家

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def DeleteSeller():
    sql_delete="Delete  From  买家   Where  买家名称 ='%s'"%(expression.get())
    cursor.execute(sql_delete)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    
def qb():
    l1["text"]=""
    sql_query="select * from 买家"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt
        l1["text"]+="\n"
#         print()        #输出每个分量

    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()
f1.pack()
entry.pack()
expression=StringVar()
empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression

butt_qs=Button(f1,text="删除买家信息",command=DeleteSeller)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询买家信息",command=qb)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 删除商品

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def DeleteSeller():
    sql_delete="Delete  From  出售的商品   Where  商品名称 ='%s'"%(expression.get())
    cursor.execute(sql_delete)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    
def qg():
    l1["text"]=""
    sql_query="select * from 出售的商品"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量

    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()
f1.pack()
entry.pack()
expression=StringVar()
empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression

butt_qs=Button(f1,text="删除商品信息",command=DeleteSeller)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询商品信息",command=qg)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 删除交易记录

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def DeleteSeller():
    sql_delete="Delete  From  交易详情   Where  交易单号 ='%s'"%(expression.get())
    cursor.execute(sql_delete)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    

def qt():
    l1["text"]=""
    sql_query="select * from 交易详情"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量

    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry.focus()
f1.pack()
entry.pack()
expression=StringVar()
empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression

butt_qs=Button(f1,text="删除交易信息",command=DeleteSeller)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询交易信息",command=qt)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # ————————————————————————————————————————————————————————分割线—————————————————————————————————————————————————————————————————————————————————————————————————

# %% [markdown]
# # 更改商品

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def AlterGoods():
    sql_alter="Update  出售的商品  set %s='%s' Where  商品名称 = '%s'"%(expression1.get(),expression2.get(),expression.get())
    cursor.execute(sql_alter)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    entry1["textvariable"]=empty
    entry2["textvariable"]=empty
    
def qg():
    l1["text"]=""
    sql_query="select * from 出售的商品"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量


    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry1=Entry(f1)
entry2=Entry(f1)

entry.focus()
f1.pack()
entry.pack()
entry1.pack()
entry2.pack()

expression=StringVar()
expression1=StringVar()
expression2=StringVar()


empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression
entry1["textvariable"]=expression1
entry2["textvariable"]=expression2

butt_qs=Button(f1,text="更改商品信息(卖家名称/商品类型/商品单价)",command=AlterGoods)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询商品信息",command=qg)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %% [markdown]
# # 更改交易详情

# %%
# import import_ipynb
# import D as sql
from tkinter import*
import pymssql 
#连接数据库
conn = pymssql.connect('localhost','meng','abc12345','跳蚤市场')  
#connect = pymssql.connect('服务器名称', '用户名', '密码', '库名')  # 建立连接
if conn:
    print("连接成功")
    
# 创建游标
cursor=conn.cursor() 

        
def AlterGoods():
    sql_alter="Update  交易详情  set %s='%s' Where  交易单号 = '%s'"%(expression1.get(),expression2.get(),expression.get())
    cursor.execute(sql_alter)   #执行某一SQL操作
    conn.commit()
    entry["textvariable"]=empty
    entry1["textvariable"]=empty
    entry2["textvariable"]=empty
    
def qt():
    l1["text"]=""
    sql_query="select * from 交易详情"    #查看交易详情
    cursor.execute(sql_query)   #执行某一SQL操作
    res=cursor.fetchall()   #操作结果付给res
    for record in res:      #record是res中的每个元组
        for col in range(len(record)):
            showtxt=str(record[col])
#             print (showtxt,end=" ")
            l1["text"]+=showtxt+" "
        l1["text"]+="\n"
#         print()        #输出每个分量

        
    

# 创建GUI
win=Tk()
f1=Frame(win)
entry=Entry(f1)
entry1=Entry(f1)
entry2=Entry(f1)

entry.focus()
f1.pack()
entry.pack()
entry1.pack()
entry2.pack()

expression=StringVar()
expression1=StringVar()
expression2=StringVar()


empty=StringVar()
empty.set('Done')
entry["textvariable"]=expression
entry1["textvariable"]=expression1
entry2["textvariable"]=expression2

butt_qs=Button(f1,text="更改交易信息(交易时间/买家/卖家/商品名称/交易数量)",command=AlterGoods)
butt_qs.pack(side='bottom')
butt_qs=Button(f1,text="查询交易信息",command=qt)
butt_qs.pack(side='bottom')

l1=Label(f1)
l1.pack()

win.mainloop()
conn.close()
# Out:
# 连接成功

# %%
# Out:
# 连接成功
